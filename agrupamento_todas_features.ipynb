# %% [markdown]
# Objetivo do Projeto
# Agrupar clientes bancários com base em características demográficas e comportamentais para identificar perfis distintos de uso dos serviços financeiros.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Carregando os dados

# %%
df1 = pd.read_csv ('~/Documents/banking-customer-clustering/bank_data.csv')
df1.head()
# Out:
#    Branch_ID     City Region  Firm_Revenue  Expenses  Profit_Margin
# 0       1000  Solapur   East      422443.0    346471          56.31
# 1       1001   Mumbai  North      211155.0    216256          79.53
# 2       1002   Nashik   West      985006.0     71777          55.31
# 3       1003  Solapur  North       55113.0    253655           2.57
# 4       1004   Nagpur   West      282701.0    148194         -14.10

# %%
df2 = pd.read_csv ('~/Documents/banking-customer-clustering/customer_data.csv')
df2.head()
# Out:
#    Customer_ID   Age Customer_Type      City Region  Bank_Name  Branch_ID
# 0       200000  56.0      Employee      Pune  North  HDFC Bank       1350
# 1       200001  69.0           NaN  Kolhapur   East  HDFC Bank       1648
# 2       200002  46.0      Business      Pune   West  HDFC Bank       1798
# 3       200003  32.0    Individual      Pune   West  HDFC Bank       1900
# 4       200004   NaN      Business  Kolhapur   East  HDFC Bank       1227

# %%
df3 = pd.read_csv ('~/Documents/banking-customer-clustering/transaction_data.csv')
df3.head()
# Out:
#    Transaction_ID  Customer_ID Account_Type  Total_Balance  \
# 0          300000       209689     Business          69339
# 1          300001       206124     Business          12825
# 2          300002       207501      Current          67753
# 3          300003       208675      Savings          67061
# 4          300004       204923     Business           8566
#
#    Transaction_Amount  Investment_Amount Investment_Type Transaction_Date
# 0              4794.0              42580   Fixed Deposit       2024-12-08
# 1              3500.0              46605   Fixed Deposit       2022-09-09
# 2              2401.0              17027   Fixed Deposit       2022-04-28
# 3              2952.0               3054   Fixed Deposit       2023-05-22
# 4              1025.0              44937   Fixed Deposit       2023-04-05

# %%
bank_data = pd.merge(df1, df2, on= 'Branch_ID', how='inner')

# %%
df = pd.merge(bank_data, df3, on='Customer_ID', how='inner')

# %%
df.head()
# Out:
#    Branch_ID   City_x Region_x  Firm_Revenue  Expenses  Profit_Margin  \
# 0       1000  Solapur     East      422443.0    346471          56.31
# 1       1000  Solapur     East      422443.0    346471          56.31
# 2       1000  Solapur     East      422443.0    346471          56.31
# 3       1000  Solapur     East      422443.0    346471          56.31
# 4       1000  Solapur     East      422443.0    346471          56.31
#
#    Customer_ID   Age Customer_Type    City_y Region_y  Bank_Name  \
# 0       204700  54.0    Individual  Kolhapur     East  HDFC Bank
# 1       204955  51.0      Business   Solapur    South  HDFC Bank
# 2       205772  57.0    Individual    Nashik     West  HDFC Bank
# 3       205772  57.0    Individual    Nashik     West  HDFC Bank
# 4       205772  57.0    Individual    Nashik     West  HDFC Bank
#
#    Transaction_ID Account_Type  Total_Balance  Transaction_Amount  \
# 0          304833      Current          57622              4676.0
# 1          300574     Business          37337              1121.0
# 2          304051      Current          26773              2924.0
# 3          307451      Current          31080               780.0
# 4          309364     Business          61386              3988.0
#
#    Investment_Amount    Investment_Type Transaction_Date
# 0              11260      Fixed Deposit       2024-04-05
# 1              27750      Fixed Deposit       2024-05-29
# 2               9480  Recurring Deposit       2025-02-14
# 3               8956      Fixed Deposit       2022-11-07
# 4              19907        Mutual Fund       2023-05-03

# %% [markdown]
# # Análise exploratória

# %%
df.shape
# Out:
# (10000, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Branch_ID           10000 non-null  int64
#  1   City_x              10000 non-null  object
#  2   Region_x            10000 non-null  object
#  3   Firm_Revenue        9433 non-null   float64
#  4   Expenses            10000 non-null  int64
#  5   Profit_Margin       10000 non-null  float64
#  6   Customer_ID         10000 non-null  int64
#  7   Age                 9499 non-null   float64
#  8   Customer_Type       9495 non-null   object
#  9   City_y              9496 non-null   object
#  10  Region_y            10000 non-null  object
#  11  Bank_Name           10000 non-null  object
#  12  Transaction_ID      10000 non-null  int64
#  13  Account_Type        10000 non-null  object
#  14  Total_Balance       10000 non-null  int64
#  15  Transaction_Amount  10000 non-null  float64
#  16  Investment_Amount   10000 non-null  int64
#  17  Investment_Type     10000 non-null  object
#  18  Transaction_Date    10000 non-null  object
# dtypes: float64(4), int64(6), object(9)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#           Branch_ID   Firm_Revenue       Expenses  Profit_Margin  \
# count  10000.000000    9433.000000   10000.000000   10000.000000
# mean    1496.861600  507974.155412  266679.728400      24.036064
# std      290.492938  277581.933403  139731.304605      42.370806
# min     1000.000000   51241.000000   20520.000000     -49.500000
# 25%     1241.000000  255785.000000  148194.000000     -12.800000
# 50%     1498.000000  510682.000000  269692.000000      22.360000
# 75%     1748.000000  740370.000000  394440.000000      61.340000
# max     1999.000000  999975.000000  499568.000000      99.970000
#
#          Customer_ID          Age  Transaction_ID  Total_Balance  \
# count   10000.000000  9499.000000     10000.00000   10000.000000
# mean   205028.182600    49.086535    304999.50000   50221.505800
# std      2909.008139    18.104528      2886.89568   28540.392011
# min    200000.000000    18.000000    300000.00000    1003.000000
# 25%    202498.750000    34.000000    302499.75000   25132.000000
# 50%    205060.000000    49.000000    304999.50000   50326.000000
# 75%    207561.000000    65.000000    307499.25000   74914.500000
# max    209999.000000    79.000000    309999.00000   99993.000000
#
#        Transaction_Amount  Investment_Amount
# count        10000.000000       10000.000000
# mean          2542.708056       25550.248400
# std           1432.677420       14108.052078
# min             51.613952        1001.000000
# 25%           1310.000000       13381.000000
# 50%           2538.500000       25708.500000
# 75%           3746.250000       37731.000000
# max           7046.296441       49998.000000

# %%
# Listando as colunas numéricas para gerar os boxplots
numerical_columns = ['Firm_Revenue', 'Expenses', 'Profit_Margin', 'Age', 'Total_Balance']

# Gerando boxplots para cada variável
for column in numerical_columns:
    plt.figure(figsize=(8, 6))
    sns.boxplot(data=df[column])
    plt.title(f'Boxplot de {column}')
    plt.xlabel(column)
    plt.show()

# %%
# Gráfico de barras para variáveis categóricas
categorical_columns = ['City_x', 'Region_x', 'Customer_Type', 'Bank_Name', 'Account_Type']

plt.figure(figsize=(14, 8))
for i, column in enumerate(categorical_columns, 1):
    plt.subplot(2, 3, i)
    sns.countplot(data=df, x=column)
    plt.title(f'Distribuição de {column}')
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
# Exemplo de agregação
df_grouped = df.groupby(['City_x', 'Region_x']).agg({
    'Firm_Revenue': 'mean',
    'Expenses': 'mean',
    'Profit_Margin': 'mean',
    'Total_Balance': 'mean',
    'Transaction_Amount': 'sum'
}).reset_index()

# Verificando a agregação
df_grouped.head()
# Out:
#      City_x Region_x   Firm_Revenue       Expenses  Profit_Margin  \
# 0  Kolhapur     East  454432.109726  295705.084388      22.091013
# 1  Kolhapur    North  477233.659306  254021.919897      19.004057
# 2  Kolhapur    South  488810.317673  281086.844262      24.363750
# 3  Kolhapur     West  481383.094907  252314.643016      17.622816
# 4    Mumbai     East  455938.596581  219449.933775      23.354735
#
#    Total_Balance  Transaction_Amount
# 0   51239.464135        1.232187e+06
# 1   50182.981912        1.019722e+06
# 2   49743.456967        1.231386e+06
# 3   50411.487805        1.141913e+06
# 4   50995.312914        1.542507e+06

# %%
# Adicionando uma coluna 'Ano-Mês'
df['Month'] = pd.to_datetime(df['Transaction_Date']).dt.to_period('M')

# Agrupando por 'Month' e somando os valores de transações e investimentos
df_monthly = df.groupby('Month')[['Transaction_Amount', 'Investment_Amount']].sum()

# Plotando a soma das transações por mês
plt.figure(figsize=(14, 6))
df_monthly['Transaction_Amount'].plot(kind='bar', color='blue', alpha=0.7, label='Transações Totais')
df_monthly['Investment_Amount'].plot(kind='bar', color='orange', alpha=0.7, label='Investimentos Totais')

plt.title('Soma de Transações e Investimentos por Mês')
plt.xlabel('Mês')
plt.ylabel('Valor Total')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Agrupando por 'Month' e 'Customer_ID' para obter a média de transações
df_customer_monthly = df.groupby(['Month', 'Customer_ID'])['Transaction_Amount'].sum().reset_index()

# Calculando a média das transações por mês
df_monthly_avg = df_customer_monthly.groupby('Month')['Transaction_Amount'].mean()

# Plotando a média de transações por cliente por mês
plt.figure(figsize=(14, 6))
df_monthly_avg.plot(kind='line', color='green')
plt.title('Média de Transações por Cliente por Mês')
plt.xlabel('Mês')
plt.ylabel('Média de Transações')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Dataprep

# %%
# Imputação dados numéricos (média)
imputer = SimpleImputer(strategy='mean')  
df['Firm_Revenue'] = imputer.fit_transform(df[['Firm_Revenue']])
df['Age'] = imputer.fit_transform(df[['Age']])

# %%
df.shape
# Out:
# (10000, 20)

# %%
# Imputação dados numéricos (moda)
# Lista das colunas categóricas
cat_cols = ['Customer_Type', 'City_y', 'Investment_Type', 'City_x', 'Region_x', 'Bank_Name', 'Account_Type']

# Imputador com a moda
imputer = SimpleImputer(strategy='most_frequent')

# Aplicando a imputação coluna a coluna
for col in cat_cols:
    df[col] = imputer.fit_transform(df[[col]])[:, 0]

# %%
df['Transaction_Date'] = pd.to_datetime(df['Transaction_Date'], errors='coerce')

# %%
df['transaction_dayofweek'] = df['Transaction_Date'].dt.dayofweek
df['transaction_day'] = df['Transaction_Date'].dt.day
df['is_weekend'] = df['transaction_dayofweek'].isin([5, 6]).astype(int)
df['days_since_first_tx'] = (df['Transaction_Date'] - df['Transaction_Date'].min()).dt.days

# %%
# Codificar variáveis categóricas:
df_encoded = pd.get_dummies(df, columns=['Customer_Type', 'Account_Type', 'Investment_Type', 'City_x', 'Region_x', 'City_y', 'Region_y', 'Bank_Name' ], drop_first=True)

# %%
df_encoded = df_encoded.drop(columns=['Transaction_Date', 'Month'])

# %%
df_encoded.corr()
# Out:
#                                    Branch_ID  Firm_Revenue  Expenses  \
# Branch_ID                           1.000000     -0.055054  0.048853
# Firm_Revenue                       -0.055054      1.000000 -0.010061
# Expenses                            0.048853     -0.010061  1.000000
# Profit_Margin                      -0.004738      0.059009  0.015453
# Customer_ID                        -0.007143      0.002300 -0.022014
# Age                                 0.011503      0.005740 -0.006827
# Transaction_ID                     -0.011005     -0.007421  0.014589
# Total_Balance                       0.001147      0.005625 -0.004495
# Transaction_Amount                  0.001778      0.003084 -0.018364
# Investment_Amount                  -0.007047      0.000062 -0.013891
# transaction_dayofweek               0.013614      0.000788 -0.000530
# transaction_day                    -0.001022      0.003296  0.007465
# is_weekend                          0.004652     -0.002592 -0.015501
# days_since_first_tx                -0.003748     -0.003474 -0.002125
# Customer_Type_Employee             -0.024609      0.019312 -0.007847
# Customer_Type_Individual            0.013806     -0.017289 -0.014713
# Account_Type_Current               -0.009939      0.007789  0.021850
# Account_Type_Savings                0.000823      0.001774 -0.009512
# Investment_Type_Mutual Fund        -0.009050     -0.015280 -0.009127
# Investment_Type_Recurring Deposit   0.007227      0.026518  0.003821
# City_x_Mumbai                       0.035817     -0.063438 -0.053266
# City_x_Nagpur                      -0.044090      0.044132  0.011101
# City_x_Nashik                       0.005820      0.005334 -0.059220
# City_x_Pune                         0.038134      0.031668  0.080411
# City_x_Solapur                     -0.037836      0.037397  0.005755
# Region_x_North                      0.014087      0.001710  0.004800
# Region_x_South                      0.023975      0.036289  0.003608
# Region_x_West                      -0.038427     -0.036979  0.017586
# City_y_Mumbai                       0.016556      0.009576 -0.010228
# City_y_Nagpur                       0.024677      0.025031  0.014578
# City_y_Nashik                      -0.017674     -0.027515 -0.012738
# City_y_Pune                        -0.027327      0.010501 -0.008481
# City_y_Solapur                      0.003232     -0.002588  0.005306
# Region_y_North                      0.007509     -0.012449 -0.005283
# Region_y_South                      0.030257      0.006474  0.004830
# Region_y_West                      -0.003056     -0.003947  0.025028
#
#                                    Profit_Margin  Customer_ID       Age  \
# Branch_ID                              -0.004738    -0.007143  0.011503
# Firm_Revenue                            0.059009     0.002300  0.005740
# Expenses                                0.015453    -0.022014 -0.006827
# Profit_Margin                           1.000000    -0.000582 -0.009449
# Customer_ID                            -0.000582     1.000000 -0.029854
# Age                                    -0.009449    -0.029854  1.000000
# Transaction_ID                          0.006605     0.001694 -0.002062
# Total_Balance                          -0.006513     0.001245  0.011463
# Transaction_Amount                     -0.001473    -0.012496 -0.008260
# Investment_Amount                       0.009610     0.007713 -0.003751
# transaction_dayofweek                   0.005495    -0.009275  0.016841
# transaction_day                         0.016969    -0.002013  0.016286
# is_weekend                              0.002315    -0.002873  0.019690
# days_since_first_tx                    -0.005376    -0.000100 -0.007884
# Customer_Type_Employee                  0.006005    -0.002473 -0.000743
# Customer_Type_Individual               -0.010568     0.011038  0.002734
# Account_Type_Current                   -0.012969    -0.009798  0.002681
# Account_Type_Savings                    0.011120     0.003163 -0.006256
# Investment_Type_Mutual Fund            -0.003447     0.011838  0.000634
# Investment_Type_Recurring Deposit       0.007856    -0.013390 -0.011099
# City_x_Mumbai                           0.022442     0.011053  0.006122
# City_x_Nagpur                           0.082705    -0.005750  0.003918
# City_x_Nashik                           0.002984     0.008163  0.019198
# City_x_Pune                            -0.022783     0.000103  0.000214
# City_x_Solapur                         -0.046905    -0.016102 -0.012890
# Region_x_North                          0.020155    -0.005033 -0.001340
# Region_x_South                         -0.003128     0.001466 -0.013018
# Region_x_West                          -0.031476     0.014213 -0.005975
# City_y_Mumbai                           0.003015     0.001404 -0.005162
# City_y_Nagpur                          -0.024143     0.002916 -0.005062
# City_y_Nashik                          -0.018149     0.020530 -0.025288
# City_y_Pune                             0.023910    -0.004209 -0.005705
# City_y_Solapur                          0.021365     0.001176  0.026754
# Region_y_North                         -0.015597    -0.009634  0.019337
# Region_y_South                         -0.002065    -0.011920 -0.029854
# Region_y_West                           0.006838     0.012425  0.005900
#
#                                    Transaction_ID  Total_Balance  \
# Branch_ID                               -0.011005       0.001147
# Firm_Revenue                            -0.007421       0.005625
# Expenses                                 0.014589      -0.004495
# Profit_Margin                            0.006605      -0.006513
# Customer_ID                              0.001694       0.001245
# Age                                     -0.002062       0.011463
# Transaction_ID                           1.000000       0.000229
# Total_Balance                            0.000229       1.000000
# Transaction_Amount                       0.008713       0.001355
# Investment_Amount                        0.000030       0.008832
# transaction_dayofweek                   -0.000272      -0.012977
# transaction_day                          0.005572      -0.013163
# is_weekend                               0.004092      -0.003468
# days_since_first_tx                      0.000311      -0.010442
# Customer_Type_Employee                  -0.001363       0.005449
# Customer_Type_Individual                 0.002272       0.002257
# Account_Type_Current                    -0.021211       0.002983
# Account_Type_Savings                     0.020859      -0.004847
# Investment_Type_Mutual Fund             -0.003113      -0.000148
# Investment_Type_Recurring Deposit        0.004723      -0.012784
# City_x_Mumbai                            0.017952       0.006071
# City_x_Nagpur                            0.004259      -0.005100
# City_x_Nashik                           -0.000774      -0.010792
# City_x_Pune                             -0.015990       0.010016
# City_x_Solapur                          -0.003687      -0.003431
# Region_x_North                           0.011716       0.011027
# Region_x_South                          -0.001724      -0.002669
# Region_x_West                            0.002208      -0.000613
# City_y_Mumbai                           -0.000002      -0.001097
# City_y_Nagpur                            0.006761      -0.006400
# City_y_Nashik                            0.001223       0.018401
# City_y_Pune                             -0.014418      -0.006719
# City_y_Solapur                           0.007510       0.006860
# Region_y_North                          -0.016322       0.009694
# Region_y_South                          -0.001642      -0.002615
# Region_y_West                            0.008040       0.001066
#
#                                    Transaction_Amount  Investment_Amount  ...  \
# Branch_ID                                    0.001778          -0.007047  ...
# Firm_Revenue                                 0.003084           0.000062  ...
# Expenses                                    -0.018364          -0.013891  ...
# Profit_Margin                               -0.001473           0.009610  ...
# Customer_ID                                 -0.012496           0.007713  ...
# Age                                         -0.008260          -0.003751  ...
# Transaction_ID                               0.008713           0.000030  ...
# Total_Balance                                0.001355           0.008832  ...
# Transaction_Amount                           1.000000           0.010953  ...
# Investment_Amount                            0.010953           1.000000  ...
# transaction_dayofweek                       -0.007963           0.001461  ...
# transaction_day                              0.004017           0.011798  ...
# is_weekend                                  -0.018064          -0.001730  ...
# days_since_first_tx                          0.010419           0.000491  ...
# Customer_Type_Employee                       0.003205           0.008113  ...
# Customer_Type_Individual                    -0.011345          -0.007017  ...
# Account_Type_Current                        -0.002400          -0.003578  ...
# Account_Type_Savings                         0.005648          -0.006554  ...
# Investment_Type_Mutual Fund                  0.010225          -0.002734  ...
# Investment_Type_Recurring Deposit           -0.002627           0.010764  ...
# City_x_Mumbai                                0.005991           0.027030  ...
# City_x_Nagpur                               -0.015289           0.001241  ...
# City_x_Nashik                               -0.001670          -0.010080  ...
# City_x_Pune                                  0.009983          -0.003722  ...
# City_x_Solapur                              -0.009054          -0.007966  ...
# Region_x_North                               0.006698          -0.019486  ...
# Region_x_South                              -0.004051           0.026955  ...
# Region_x_West                               -0.006805          -0.023848  ...
# City_y_Mumbai                               -0.021456          -0.001900  ...
# City_y_Nagpur                               -0.000609           0.004584  ...
# City_y_Nashik                                0.001343           0.002827  ...
# City_y_Pune                                  0.005747          -0.005841  ...
# City_y_Solapur                               0.021188          -0.017918  ...
# Region_y_North                              -0.000423           0.010398  ...
# Region_y_South                               0.000189           0.019725  ...
# Region_y_West                               -0.005249          -0.018700  ...
#
#                                    Region_x_South  Region_x_West  \
# Branch_ID                                0.023975      -0.038427
# Firm_Revenue                             0.036289      -0.036979
# Expenses                                 0.003608       0.017586
# Profit_Margin                           -0.003128      -0.031476
# Customer_ID                              0.001466       0.014213
# Age                                     -0.013018      -0.005975
# Transaction_ID                          -0.001724       0.002208
# Total_Balance                           -0.002669      -0.000613
# Transaction_Amount                      -0.004051      -0.006805
# Investment_Amount                        0.026955      -0.023848
# transaction_dayofweek                   -0.003215       0.004490
# transaction_day                          0.025889      -0.021025
# is_weekend                              -0.001432       0.008809
# days_since_first_tx                     -0.005788      -0.000117
# Customer_Type_Employee                   0.011146       0.006341
# Customer_Type_Individual                -0.000887       0.000628
# Account_Type_Current                    -0.011929       0.009382
# Account_Type_Savings                     0.015448      -0.007964
# Investment_Type_Mutual Fund             -0.008952       0.015681
# Investment_Type_Recurring Deposit        0.006232      -0.010498
# City_x_Mumbai                           -0.037609      -0.014494
# City_x_Nagpur                           -0.054076      -0.004007
# City_x_Nashik                            0.016707       0.036009
# City_x_Pune                              0.038428      -0.008501
# City_x_Solapur                           0.016733      -0.022888
# Region_x_North                          -0.320201      -0.306801
# Region_x_South                           1.000000      -0.327958
# Region_x_West                           -0.327958       1.000000
# City_y_Mumbai                            0.008248       0.020167
# City_y_Nagpur                            0.001906      -0.023565
# City_y_Nashik                           -0.009205       0.003438
# City_y_Pune                              0.002009       0.002201
# City_y_Solapur                          -0.023163       0.016289
# Region_y_North                          -0.004618      -0.000075
# Region_y_South                           0.002262       0.024397
# Region_y_West                           -0.026320      -0.012086
#
#                                    City_y_Mumbai  City_y_Nagpur  \
# Branch_ID                               0.016556       0.024677
# Firm_Revenue                            0.009576       0.025031
# Expenses                               -0.010228       0.014578
# Profit_Margin                           0.003015      -0.024143
# Customer_ID                             0.001404       0.002916
# Age                                    -0.005162      -0.005062
# Transaction_ID                         -0.000002       0.006761
# Total_Balance                          -0.001097      -0.006400
# Transaction_Amount                     -0.021456      -0.000609
# Investment_Amount                      -0.001900       0.004584
# transaction_dayofweek                   0.000514       0.003164
# transaction_day                         0.004234      -0.014190
# is_weekend                             -0.008662       0.003428
# days_since_first_tx                     0.005047       0.007618
# Customer_Type_Employee                  0.011896      -0.000234
# Customer_Type_Individual                0.009689       0.000365
# Account_Type_Current                    0.003859      -0.003468
# Account_Type_Savings                   -0.022459       0.002756
# Investment_Type_Mutual Fund             0.008419      -0.004899
# Investment_Type_Recurring Deposit      -0.009766       0.018722
# City_x_Mumbai                           0.010970      -0.010524
# City_x_Nagpur                          -0.011850      -0.001387
# City_x_Nashik                           0.008695      -0.045071
# City_x_Pune                            -0.005695       0.016214
# City_x_Solapur                          0.005826       0.030906
# Region_x_North                         -0.029164      -0.004623
# Region_x_South                          0.008248       0.001906
# Region_x_West                           0.020167      -0.023565
# City_y_Mumbai                           1.000000      -0.226112
# City_y_Nagpur                          -0.226112       1.000000
# City_y_Nashik                          -0.227665      -0.184550
# City_y_Pune                            -0.234775      -0.190314
# City_y_Solapur                         -0.220994      -0.179143
# Region_y_North                          0.009180      -0.003120
# Region_y_South                          0.005117       0.011091
# Region_y_West                          -0.013856       0.001370
#
#                                    City_y_Nashik  City_y_Pune  City_y_Solapur  \
# Branch_ID                              -0.017674    -0.027327        0.003232
# Firm_Revenue                           -0.027515     0.010501       -0.002588
# Expenses                               -0.012738    -0.008481        0.005306
# Profit_Margin                          -0.018149     0.023910        0.021365
# Customer_ID                             0.020530    -0.004209        0.001176
# Age                                    -0.025288    -0.005705        0.026754
# Transaction_ID                          0.001223    -0.014418        0.007510
# Total_Balance                           0.018401    -0.006719        0.006860
# Transaction_Amount                      0.001343     0.005747        0.021188
# Investment_Amount                       0.002827    -0.005841       -0.017918
# transaction_dayofweek                   0.003084     0.004152       -0.006283
# transaction_day                        -0.011134    -0.001562        0.009851
# is_weekend                              0.011943     0.001309        0.005098
# days_since_first_tx                     0.005845     0.001335       -0.026404
# Customer_Type_Employee                 -0.000088     0.027131       -0.033246
# Customer_Type_Individual                0.015222    -0.041439        0.015374
# Account_Type_Current                    0.009909     0.001771        0.001732
# Account_Type_Savings                    0.000980     0.005658        0.021096
# Investment_Type_Mutual Fund             0.009142    -0.006264       -0.002219
# Investment_Type_Recurring Deposit       0.000546     0.000131       -0.008553
# City_x_Mumbai                          -0.004781     0.011291        0.013202
# City_x_Nagpur                          -0.012769     0.014815       -0.000108
# City_x_Nashik                           0.012441     0.019725        0.012225
# City_x_Pune                             0.005789     0.000790       -0.029815
# City_x_Solapur                         -0.005159    -0.041999        0.002643
# Region_x_North                          0.014244     0.008108        0.016374
# Region_x_South                         -0.009205     0.002009       -0.023163
# Region_x_West                           0.003438     0.002201        0.016289
# City_y_Mumbai                          -0.227665    -0.234775       -0.220994
# City_y_Nagpur                          -0.184550    -0.190314       -0.179143
# City_y_Nashik                           1.000000    -0.191621       -0.180373
# City_y_Pune                            -0.191621     1.000000       -0.186006
# City_y_Solapur                         -0.180373    -0.186006        1.000000
# Region_y_North                          0.006606    -0.004780       -0.010844
# Region_y_South                         -0.007192    -0.016483        0.012059
# Region_y_West                           0.002886     0.013239        0.000773
#
#                                    Region_y_North  Region_y_South  \
# Branch_ID                                0.007509        0.030257
# Firm_Revenue                            -0.012449        0.006474
# Expenses                                -0.005283        0.004830
# Profit_Margin                           -0.015597       -0.002065
# Customer_ID                             -0.009634       -0.011920
# Age                                      0.019337       -0.029854
# Transaction_ID                          -0.016322       -0.001642
# Total_Balance                            0.009694       -0.002615
# Transaction_Amount                      -0.000423        0.000189
# Investment_Amount                        0.010398        0.019725
# transaction_dayofweek                    0.012611       -0.004697
# transaction_day                          0.000197       -0.009212
# is_weekend                               0.002809        0.005928
# days_since_first_tx                     -0.005045        0.018990
# Customer_Type_Employee                  -0.018345        0.004879
# Customer_Type_Individual                 0.026155        0.012581
# Account_Type_Current                    -0.020178        0.012638
# Account_Type_Savings                     0.013489       -0.019523
# Investment_Type_Mutual Fund             -0.004564       -0.011323
# Investment_Type_Recurring Deposit        0.020325       -0.003203
# City_x_Mumbai                           -0.021304       -0.008788
# City_x_Nagpur                            0.013490        0.013641
# City_x_Nashik                            0.022723       -0.027559
# City_x_Pune                              0.001381       -0.003222
# City_x_Solapur                          -0.020141        0.037405
# Region_x_North                           0.004269       -0.009338
# Region_x_South                          -0.004618        0.002262
# Region_x_West                           -0.000075        0.024397
# City_y_Mumbai                            0.009180        0.005117
# City_y_Nagpur                           -0.003120        0.011091
# City_y_Nashik                            0.006606       -0.007192
# City_y_Pune                             -0.004780       -0.016483
# City_y_Solapur                          -0.010844        0.012059
# Region_y_North                           1.000000       -0.329920
# Region_y_South                          -0.329920        1.000000
# Region_y_West                           -0.342732       -0.329313
#
#                                    Region_y_West
# Branch_ID                              -0.003056
# Firm_Revenue                           -0.003947
# Expenses                                0.025028
# Profit_Margin                           0.006838
# Customer_ID                             0.012425
# Age                                     0.005900
# Transaction_ID                          0.008040
# Total_Balance                           0.001066
# Transaction_Amount                     -0.005249
# Investment_Amount                      -0.018700
# transaction_dayofweek                  -0.005511
# transaction_day                        -0.008530
# is_weekend                             -0.006393
# days_since_first_tx                    -0.010543
# Customer_Type_Employee                 -0.015222
# Customer_Type_Individual               -0.014981
# Account_Type_Current                   -0.001082
# Account_Type_Savings                    0.011722
# Investment_Type_Mutual Fund             0.005818
# Investment_Type_Recurring Deposit      -0.008689
# City_x_Mumbai                           0.023540
# City_x_Nagpur                          -0.013095
# City_x_Nashik                           0.010755
# City_x_Pune                             0.010743
# City_x_Solapur                         -0.038230
# Region_x_North                          0.013324
# Region_x_South                         -0.026320
# Region_x_West                          -0.012086
# City_y_Mumbai                          -0.013856
# City_y_Nagpur                           0.001370
# City_y_Nashik                           0.002886
# City_y_Pune                             0.013239
# City_y_Solapur                          0.000773
# Region_y_North                         -0.342732
# Region_y_South                         -0.329313
# Region_y_West                           1.000000
#
# [36 rows x 36 columns]

# %%
df_encoded.var().sort_values()
# Out:
# City_x_Nagpur                        1.249795e-01
# City_y_Solapur                       1.268117e-01
# City_y_Nagpur                        1.309191e-01
# City_y_Nashik                        1.321583e-01
# City_x_Solapur                       1.344814e-01
# City_y_Pune                          1.377888e-01
# City_x_Pune                          1.380566e-01
# City_x_Nashik                        1.434121e-01
# City_x_Mumbai                        1.441293e-01
# City_y_Mumbai                        1.705494e-01
# Region_x_North                       1.773875e-01
# Region_x_West                        1.819494e-01
# Region_y_South                       1.827818e-01
# Region_y_West                        1.899450e-01
# Region_x_South                       1.899940e-01
# Region_y_North                       1.902877e-01
# is_weekend                           2.021030e-01
# Customer_Type_Individual             2.180166e-01
# Investment_Type_Mutual Fund          2.220329e-01
# Investment_Type_Recurring Deposit    2.223998e-01
# Account_Type_Savings                 2.226651e-01
# Account_Type_Current                 2.232246e-01
# Customer_Type_Employee               2.343233e-01
# transaction_dayofweek                4.008160e+00
# transaction_day                      7.852440e+01
# Age                                  3.113508e+02
# Profit_Margin                        1.795285e+03
# Branch_ID                            8.438615e+04
# days_since_first_tx                  1.009686e+05
# Transaction_Amount                   2.052565e+06
# Transaction_ID                       8.334167e+06
# Customer_ID                          8.462328e+06
# Investment_Amount                    1.990371e+08
# Total_Balance                        8.145540e+08
# Expenses                             1.952484e+10
# Firm_Revenue                         7.268246e+10
# dtype: float64

# %%
# Padronizar os dados numéricos:
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_encoded.drop('Customer_ID', axis=1))

# %%
X_scaled.shape
# Out:
# (10000, 35)

# %% [markdown]
# # Agrupamento kmeans

# %%
inertias = []
silhouette_scores = []
k_range = range(20, 1500, 100)

# %%
for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    cluster_labels = kmeans.fit_predict(X_scaled)
    
    # Armazena a inércia
    inertias.append(kmeans.inertia_)
    
    # Armazena o silhouette score
    silhouette_scores.append(silhouette_score(X_scaled, cluster_labels))

# %%
import matplotlib.pyplot as plt

# Criando os subplots primeiro
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Gráfico do Cotovelo
ax1.plot(k_range, inertias, marker='o')
ax1.set_title('Método do Cotovelo (Inércia)')
ax1.set_xlabel('Número de Clusters (k)')
ax1.set_ylabel('Inércia')
ax1.grid(True)

# Gráfico do Silhouette
ax2.plot(k_range, silhouette_scores, marker='o', color='green')
ax2.set_title('Silhouette Score')
ax2.set_xlabel('Número de Clusters (k)')
ax2.set_ylabel('Silhouette Score')
ax2.grid(True)

# Ajustando o layout para não sobrepor os gráficos
plt.tight_layout()

# Exibindo os gráficos
plt.show()

# %%
inertias = []
silhouette_scores = []
k_range = range(2, 20, 2)

# %%
for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    cluster_labels = kmeans.fit_predict(X_scaled)
    
    # Armazena a inércia
    inertias.append(kmeans.inertia_)
    
    # Armazena o silhouette score
    silhouette_scores.append(silhouette_score(X_scaled, cluster_labels))
# Out:
# c:\Users\bianc\Documents\Itau-Analise-de-Credito\.venv\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] O sistema não pode encontrar o arquivo especificado
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\bianc\Documents\Itau-Analise-de-Credito\.venv\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^

# %%
import matplotlib.pyplot as plt

# Criando os subplots primeiro
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Gráfico do Cotovelo
ax1.plot(k_range, inertias, marker='o')
ax1.set_title('Método do Cotovelo (Inércia)')
ax1.set_xlabel('Número de Clusters (k)')
ax1.set_ylabel('Inércia')
ax1.grid(True)

# Gráfico do Silhouette
ax2.plot(k_range, silhouette_scores, marker='o', color='green')
ax2.set_title('Silhouette Score')
ax2.set_xlabel('Número de Clusters (k)')
ax2.set_ylabel('Silhouette Score')
ax2.grid(True)

# Ajustando o layout para não sobrepor os gráficos
plt.tight_layout()

# Exibindo os gráficos
plt.show()
